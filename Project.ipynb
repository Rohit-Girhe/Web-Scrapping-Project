# %% [markdown]
# # Project: Shiksha.com College Analysis
# `Website` = https://www.shiksha.com/engineering/colleges/b-tech-colleges-india
# - This notebook outlines the full web scraping and data collection process for analyzing B.Tech colleges in India, following the project guidelines (400+ rows, 8+ features).

# %% [markdown]
# ## Phase 1: Define the Problem Statement
# **Problem Statement:**

# %% [markdown]
# -------------------
# --------------------

# %% [markdown]
# ### 2. Import Libraries
# Now, we import all the libraries we will use.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
from random import randint

# %%
url = "https://anikai.to/genres/adventure"
headers = headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
    }
response = requests.get(url,headers = headers)
response.status_code
# Out:
# 200

# %%
#Extracting 
html_code = response.text

# %%
soup = BeautifulSoup(html_code)
soup.text[:2000]
# Out:
# 'Adventure Anime - Watch Online with SUB, DUB - AnimeKAI                       Filter          Genres  Action Adventure Avant Garde Boys Love Comedy Demons Drama Ecchi Fantasy Girls Love Gourmet Harem Horror Isekai Iyashikei Josei Kids Magic Mahou Shoujo Martial Arts Mecha Military Music Mystery Parody Psychological Reverse Harem Romance School Sci-Fi Seinen Shoujo Shounen Slice of Life Space Sports Super Power Supernatural Suspense Thriller Vampire    Types  Movies TV Series OVAs ONAs Specials   New Releases Updates OnGoing Recent  Random  Watch2gether    en jp                 Adventure Anime 3,645 anime            Type     Movie    TV    OVA    ONA    Special    Music        Genre      Action    Adventure    Avant Garde    Boys Love    Comedy    Demons    Drama    Ecchi    Fantasy    Girls Love    Gourmet    Harem    Horror    Isekai    Iyashikei    Josei    Kids    Magic    Mahou Shoujo    Martial Arts    Mecha    Military    Music    Mystery    Parody    Psychological    Reverse Harem    Romance    School    Sci-Fi    Seinen    Shoujo    Shounen    Slice of Life    Space    Sports    Super Power    Supernatural    Suspense    Thriller    Vampire         Status     Not Yet Aired    Releasing    Completed        Sort by     Updated date    Release date    End date    Added date    Trending    Name A-Z    Average score    MAL score    Total views    Total bookmarks    Total episodes       Filter         Season     Fall    Summer    Spring    Winter    Unknown        Year     2025    2024    2023    2022    2021    2020    2019    2018    2017    2016    2015    2014    2013    2012    2011    2010    2009    2008    2007    2006    2005    2004    2003    2002    2001    2000    1990s    1980s    1970s    1960s    1950s    1940s    1930s    1920s    1910s    1900s        Rating     G - All Ages    PG - Children    PG 13 - Teens 13 and Older    R - 17+, Violence & Profanity    R+ - Profanity & Mild Nudity    Rx - Hentai       Country    China    Japan     Language   '

# %%
soup = BeautifulSoup(response.text, 'html.parser')
